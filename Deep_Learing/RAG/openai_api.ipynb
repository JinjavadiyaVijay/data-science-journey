# %%
from dotenv import load_dotenv
import os
load_dotenv()

OPENAI_API_KEY = "sk-O8nvVoNtdCIXJm42JY6kwZRPJZpZZnix8ZLbkZsRA3rdnVZR"

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (2.44.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (4.68.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\ProgramData\miniconda3\envs\ai\Lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# Promt => openai model => response
# https://developers.openai.com/api/reference/resources/responses
OPENAI_API_KEY = "sk-sMARDr3sG1Ki3iklAcC2RjS4SQkasulwhWOKmBesvMoyKgMS"
from openai import OpenAI 
client = OpenAI(api_key = OPENAI_API_KEY)

response = client.responses.create(
    model ="gpt-5",
    input = "Write a short bedtime story about a unicorn."
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[9], line 6
#       2 OPENAI_API_KEY = "sk-sMARDr3sG1Ki3iklAcC2RjS4SQkasulwhWOKmBesvMoyKgMS"
#       3 from openai import OpenAI
#       4 client = OpenAI(api_key = OPENAI_API_KEY)
#       5
# ----> 6 response = client.responses.create(
#       7     model ="gpt-5",
#       8     input = "Write a short bedtime story about a unicorn."
#       9 )
#
# File c:\ProgramData\miniconda3\envs\ai\Lib\site-packages\openai\resources\responses\responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File c:\ProgramData\miniconda3\envs\ai\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\ProgramData\miniconda3\envs\ai\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-sMARD***************************************KgMS. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
#!pip install -U google-genai

# %%
import os
from google import genai

client = genai.Client(
    api_key=os.getenv("GOOGLE_KEY")
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Write a short bedtime story about a unicorn."
)

print(response.text)
# Out:
# c:\ProgramData\miniconda3\envs\ai\Lib\site-packages\requests\__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Once upon a time, in the Whispering Woods, lived a beautiful unicorn named Luna. Her coat was like freshly fallen snow, and her horn spiraled up to a soft, pearly point that glowed faintly in the twilight.
#
# Luna loved the quiet time when the sun began to dip below the tallest trees, painting the sky in sleepy oranges and gentle purples. Tonight, she trotted softly along a mossy path, her hooves barely rustling the fallen leaves.
#
# She saw the little dormice snuggling into their cozy nests, heard a baby owl give a soft, sleepy "hoo," and watched as the wildflowers slowly folded their petals, ready for a night's rest. The air grew cool and sweet with the scent of night-blooming jasmine.
#
# As the first tiny stars began to twinkle like scattered diamonds, Luna found her special clearing. It was a place where the moss was extra soft, and moonbeams always found their way through the leaves, painting silver stripes on the ground.
#
# She lay down, curling her long legs beneath her. Her pearly horn rested gently on the cool moss, and its soft glow pulsed like a quiet heartbeat, sending out tiny, shimmering goodnight wishes to every sleepy creature in the woods.
#
# Luna closed her eyes, feeling safe and loved, wrapped in the quiet hug of the forest. She dreamed of galloping through fields of stardust and chasing gentle moonbeams.
#
# And as Luna drifted off to sleep, feeling peaceful and warm, you can close your eyes too, little one. Dream sweet dreams, just like Luna, until the morning light. Goodnight.
