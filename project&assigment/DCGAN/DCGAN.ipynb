# %%
import os
from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
from PIL import Image

# %%
class imageProcessor:
    def __init__(self,root_dir_path, transformations =None):
        self.root_dir_path = root_dir_path
        self.transformations=transformations
        all_img_paths = [
            os.path.join(root_dir_path, img)
            for img in os.listdir(self.root_dir_path)
            ]

    def __len__(self):
        return len(self.all_img_paths)

    def get_img(self,idx):
        img_path = self.all_img_paths[idx]
        image = Image.open(img_path).convert("RGB")

        if transformations:
            img = transformations(img)
            return img

# %%
root_dir_path = "Prime_/Deep_Learing/GANs/img_align_celeba"

transformations = transforms.Compose(
    [
        transforms.CenterCrop(178),
        transforms.Resize(64),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]
)

# %%
Dataset = imageProcessor(root_dir_path,transformations)
print(f"loaded images:{len(Dataset)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Dataset = imageProcessor(root_dir_path,transformations)
#       2 print(f"loaded images:{len(Dataset)}")
#
# Cell In[2], line 5, in imageProcessor.__init__(self, root_dir_path, transformations)
#       2     def __init__(self,root_dir_path, transformations =None):
#       3         self.root_dir_path = root_dir_path
#       4         self.transformations=transformations
# ----> 5         all_img_paths = [os.path.join(root_dir_path,img) for img in range(os.listdir(self.root_dir_path))]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Prime_/Deep_Learing/GANs/img_align_celeba'
