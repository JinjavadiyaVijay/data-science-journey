# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score , accuracy_score

# %%
df = datasets.load_diabetes(as_frame=True).frame

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
x = df.drop("target", axis=1)

# %%
y= df["target"]

# %%
x_train,x_test,y_train, y_test= train_test_split(
    x,y,random_state=42
)

# %%
from sklearn.preprocessing import MinMaxScaler
min_sclr = MinMaxScaler()

y =min_sclr.fit_transform(y.values.reshape(-1,1)).ravel()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

reg = RandomForestRegressor(random_state=42)

params = {
    "n_estimators":[100,200,300],
    "max_depth":[3,5,7,None],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4]
}

grid = GridSearchCV(
    reg,
    params,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

grid.fit(x_train,y_train)

print("Best params:",grid.best_params_)
# Out:
# Best params: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}

# %%
reg = RandomForestRegressor(max_depth=4,min_samples_leaf=3,min_samples_split=2 , n_estimators=200,oob_score=True)

reg.fit(x_train,y_train)
y_pred_train = reg.predict(x_train)
y_pred = reg.predict(x_test)

print("oob score ",reg.oob_score_)
print("r2_score of train : ",r2_score(y_train,y_pred_train))
print("r2_score of test : ",r2_score(y_test,y_pred))
# Out:
# oob score  0.4366004885260081
# r2_score of train :  0.6484989646527337
# r2_score of test :  0.49817820959876247
