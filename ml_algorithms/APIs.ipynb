# %%
import requests

# %%
url = "https://stephen-king-api.onrender.com/api/books"
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
j_data = res.json()

# %%
import pandas as pd 
df = pd.json_normalize(j_data["data"])

# %%
df
# Out:
#     id  Year          Title         handle        Publisher  \
# 0    1  1974         Carrie         carrie        Doubleday
# 1    2  1975    Salem's Lot    salem-s-lot        Doubleday
# 2    3  1977    The Shining    the-shining        Doubleday
# 3    4  1977           Rage           rage     Signet Books
# 4    5  1978      The Stand      the-stand        Doubleday
# ..  ..   ...            ...            ...              ...
# 58  59  2018   The Outsider   the-outsider         Scribner
# 59  60  2018      Elevation      elevation         Scribner
# 60  61  2019  The Institute  the-institute         Scribner
# 61  62  2021          Later          later  Hard Case Crime
# 62  63  2021  Billy Summers  billy-summers         Scribner
#
#                  ISBN  Pages  \
# 0   978-0-385-08695-0    199
# 1   978-0-385-00751-1    439
# 2   978-0-385-12167-5    447
# 3   978-0-451-07645-8    211
# 4   978-0-385-12168-2    823
# ..                ...    ...
# 58  978-1-50118-098-9    576
# ...

# %%
df.columns
# Out:
# Index(['id', 'Year', 'Title', 'handle', 'Publisher', 'ISBN', 'Pages', 'Notes',
#        'created_at', 'villains'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          63 non-null     int64
#  1   Year        63 non-null     int64
#  2   Title       63 non-null     object
#  3   handle      63 non-null     object
#  4   Publisher   63 non-null     object
#  5   ISBN        63 non-null     object
#  6   Pages       63 non-null     int64
#  7   Notes       63 non-null     object
#  8   created_at  63 non-null     object
#  9   villains    63 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ KB

# %%
df = df [['id','Year','Title','handle']]

# %%
df
# Out:
#     id  Year          Title         handle
# 0    1  1974         Carrie         carrie
# 1    2  1975    Salem's Lot    salem-s-lot
# 2    3  1977    The Shining    the-shining
# 3    4  1977           Rage           rage
# 4    5  1978      The Stand      the-stand
# ..  ..   ...            ...            ...
# 58  59  2018   The Outsider   the-outsider
# 59  60  2018      Elevation      elevation
# 60  61  2019  The Institute  the-institute
# 61  62  2021          Later          later
# 62  63  2021  Billy Summers  billy-summers
#
# [63 rows x 4 columns]
